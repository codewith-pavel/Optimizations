# %% [markdown]
# # Dataset Preprocessing

# %%
# While Model training
# 1. --- Print model summary (trainable, non-trainable, total parameters) 
# 2. --- while compiling the model, add other metrics like roc_auc score, precision, recall,f1-score,specifity,sensivity,accuracy,loss (training and validation both)
# 3. --- Plot metrics curves VS epochs like mentioned in 2 
# 4. --- Plot confusion matrix like training, validation, test dataset 
# 5. --- Implement early stopping with 100 epochs
# 6. --- records total time (training, testing, validation) and also What GPU you are using it.
# 7. ---- Save the models as well ( .hdf5 format for loading the trained weights)
# 8. ---- keep similar loss functions, optimizers, learning rate, epochs, ...etc

# %%
# !pip install keras tensorflow
# Out:
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (3.3.3)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (2.16.1)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras) (0.11.0)
# Requirement already satisfied: ml-dtypes in /opt/conda/lib/python3.10/site-packages (from keras) (0.3.2)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.1.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow) (3.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.5)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

import numpy as np

import pandas as pd

import os

from glob import glob

import seaborn as sns

from PIL import Image

np.random.seed(123)

from sklearn.preprocessing import label_binarize

from sklearn.metrics import confusion_matrix

import itertools

import tensorflow as tf

from tensorflow import keras

from tensorflow.keras.utils import to_categorical # used for converting labels to one-hot-encoding

from keras.models import Sequential

from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D

from keras import backend as K

import itertools

from keras.layers import BatchNormalization

from tensorflow.keras.utils import to_categorical # convert to one-hot-encoding



from keras.optimizers import Adam

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from keras.callbacks import ReduceLROnPlateau

from sklearn.model_selection import train_test_split

# %%
dataset_path = '/kaggle/input/skin-cancer-mnist-ham10000'

# %%
#1. Function to plot model's validation loss and validation accuracy

def plot_model_history(model_history):

    fig, axs = plt.subplots(1,2,figsize=(15,5))

    # summarize history for accuracy

    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])

    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])

    axs[0].set_title('Model Accuracy')

    axs[0].set_ylabel('Accuracy')

    axs[0].set_xlabel('Epoch')

    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)

    axs[0].legend(['train', 'val'], loc='best')

    # summarize history for loss

    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])

    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])

    axs[1].set_title('Model Loss')

    axs[1].set_ylabel('Loss')

    axs[1].set_xlabel('Epoch')

    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)

    axs[1].legend(['train', 'val'], loc='best')

    plt.show()

# %%
df = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')

df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lesion_id     10015 non-null  object
#  1   image_id      10015 non-null  object
#  2   dx            10015 non-null  object
#  3   dx_type       10015 non-null  object
#  4   age           9958 non-null   float64
#  5   sex           10015 non-null  object
#  6   localization  10015 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 547.8+ KB

# %%
df.shape
# Out:
# (10015, 7)

# %%
lesion_type_dict = {

    'nv': 'Melanocytic nevi',

    'mel': 'Melanoma',

    'bkl': 'Benign keratosis-like lesions ',

    'bcc': 'Basal cell carcinoma',

    'akiec': 'Actinic keratoses',

    'vasc': 'Vascular lesions',

    'df': 'Dermatofibroma'

}

base_skin_dir = '/kaggle/input/skin-cancer-mnist-ham10000'

# %%
import os

from glob import glob



# Use glob to get a list of file paths

image_paths = glob(os.path.join(base_skin_dir, '*', '*.jpg'))



# Create a dictionary mapping image IDs to file paths

imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x for x in image_paths}

# %%
df['path'] = df['image_id'].map(imageid_path_dict.get)

df['cell_type'] = df['dx'].map(lesion_type_dict.get)

df['cell_type_idx'] = pd.Categorical(df['cell_type']).codes



df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                                 path  \
# 0  /kaggle/input/skin-cancer-mnist-ham10000/ham10...
# 1  /kaggle/input/skin-cancer-mnist-ham10000/ham10...
# 2  /kaggle/input/skin-cancer-mnist-ham10000/ham10...
# 3  /kaggle/input/skin-cancer-mnist-ham10000/ham10...
# 4  /kaggle/input/skin-cancer-mnist-ham10000/ham10...
#
#                         cell_type  cell_type_idx
# 0  Benign keratosis-like lesions               2
# 1  Benign keratosis-like lesions               2
# 2  Benign keratosis-like lesions               2
# 3  Benign keratosis-like lesions               2
# 4  Benign keratosis-like lesions               2

# %%
df.isna().sum()
# Out:
# lesion_id         0
# image_id          0
# dx                0
# dx_type           0
# age              57
# sex               0
# localization      0
# path              0
# cell_type         0
# cell_type_idx     0
# dtype: int64

# %%
df['age'].fillna((df['age'].mean()), inplace=True)
# Out:
# /tmp/ipykernel_23/1123070014.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna((df['age'].mean()), inplace=True)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
sns.set_style('whitegrid')

colors = ['#87ace8','#e3784d', 'green']

fig,axes = plt.subplots(figsize=(12,8))



ax = sns.countplot(x='sex',data=df, palette = 'Paired')

for container in ax.containers:

    ax.bar_label(container)

plt.title('Gender-wise Distribution')

plt.xticks(rotation=45)

plt.show()

# %%
sns.set_style('whitegrid')

fig,axes = plt.subplots(figsize=(12,8))

ax = sns.countplot(x='cell_type',data=df, order = df['cell_type'].value_counts().index, palette = 'Paired')

for container in ax.containers:

    ax.bar_label(container)

plt.title('Cell Types Skin Cancer Affected patients')

plt.xticks(rotation=45)

plt.show()

# %%
sns.set_style('whitegrid')

fig,axes = plt.subplots(figsize=(12,8))

ax = sns.countplot(x='cell_type',hue='sex', data=df, order = df['cell_type'].value_counts().index, palette = 'Paired')

for container in ax.containers:

    ax.bar_label(container)

plt.title('Cell Types Frequencies')

plt.xticks(rotation=45)

plt.show()

# %%
sns.set_style('whitegrid')

fig,axes = plt.subplots(figsize=(12,8))

ax = sns.countplot(x='dx_type',data=df, order = df['dx_type'].value_counts().index, palette = 'flare')

for container in ax.containers:

    ax.bar_label(container)

plt.title('Cell Types Frequencies')

plt.xticks(rotation=45)

plt.show()

# %%
sns.set_style('whitegrid')

fig,axes = plt.subplots(figsize=(12,8))

ax = sns.countplot(x='dx_type',hue='sex', data=df, order = df['dx_type'].value_counts().index, palette = 'flare')

for container in ax.containers:

    ax.bar_label(container)

plt.title('Cell Types Frequencies')

plt.xticks(rotation=45)

plt.show()

# %%
sns.set_style('whitegrid')

fig,axes = plt.subplots(figsize=(12,8))

ax = sns.histplot(data=df, x='age')

plt.title('Age Histogram')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
size = (64, 64)

df['image'] = df['path'].map(lambda x: np.asarray(Image.open(x).resize(size))/ 255)

# %%
arr = df.iloc[1]['image']

#Image.fromarray(arr)

plt.imshow(arr)

plt.axis('off')

plt.show()

# %%
n_samples = 5

fig, m_axs = plt.subplots(7, n_samples, figsize = (12,12))

for n_axs, (type_name, type_rows) in zip(m_axs,

                                         df.sort_values(['cell_type']).groupby('cell_type')):

    n_axs[0].set_title(type_name)

    for c_ax, (_, c_row) in zip(n_axs, type_rows.sample(n_samples, random_state=42).iterrows()):

        c_ax.imshow(c_row['image'])

        c_ax.axis('off')

# fig.savefig('category_samples.png', dpi=300)

# %%
df['dx'].value_counts()
# Out:
# dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64

# %%
def aug_brightness(img_arr):

    aug_arr = tf.image.stateless_random_brightness(img_arr, 0.7, seed)

    aur_arr = np.array(aug_arr)



    return aug_arr

# %%
def aug_contrast(img_arr):

    aug_arr = tf.image.stateless_random_contrast(img_arr, 0.2, 0.8, seed)

    aur_arr = np.array(aug_arr)



    return aug_arr

# %%
def aug_flip_left_right(img_arr):

    aug_arr = tf.image.stateless_random_flip_left_right(img_arr, seed).numpy().tolist()

    aur_arr = np.array(aug_arr)



    return aug_arr

# %%
def aug_flip_up_down(img_arr):

    aug_arr = tf.image.stateless_random_flip_up_down(img_arr, seed).numpy().tolist()

    aur_arr = np.array(aug_arr)



    return aug_arr

# %%
def aug_hue(img_arr):

    aug_arr = tf.image.stateless_random_hue(img_arr, 0.5, seed)

    aur_arr = np.array(aug_arr)



    return aug_arr

# %%
def aug_saturation(img_arr):

    aug_arr = tf.image.stateless_random_saturation(img_arr, 0.1, 1, seed)

    aur_arr = np.array(aug_arr)



    return aug_arr

# %%
func_list = [aug_brightness, aug_contrast, aug_flip_left_right, aug_flip_up_down, aug_hue, aug_saturation]

# %%
from IPython.display import clear_output

def random_augmentation(images, dx, num_of_samples):

    new_images = []

    all_indices = []

    while (len(new_images) < num_of_samples):

        indices = np.random.randint(images.shape[0], size=6)

        r = list(map(lambda x, y: x(y), func_list, images.iloc[indices]))

        r = [np.array(tensor) for tensor in r]

        new_images.extend(r)

        all_indices.extend(indices)

        clear_output(wait=True)

        print(str(len(new_images)) + '/' + str(num_of_samples))



    new_images = pd.DataFrame({'dx': dx, 'image': new_images})



    return all_indices, new_images

# %%
nv_df = df[df['dx'] == 'nv']

df_df = df[df['dx'] == 'df']

vasc_df = df[df['dx'] == 'vasc']

akiec_df = df[df['dx'] == 'akiec']

bcc_df = df[df['dx'] == 'bcc']

bkl_df = df[df['dx'] == 'bkl']

mel_df = df[df['dx'] == 'mel']

# %%
seed = (4,2)

# %%
max_count = 10000

nv_count = (df['dx'] == 'nv').sum()

mel_count = (df['dx'] == 'mel').sum()

bkl_count = (df['dx'] == 'bkl').sum()

bcc_count = (df['dx'] == 'bcc').sum()

akiec_count = (df['dx'] == 'akiec').sum()

vasc_count = (df['dx'] == 'vasc').sum()

df_count = (df['dx'] == 'df').sum()

# %%
# df_images = df_df['image']

# df_indices, df_new_images = random_augmentation(df_images, 'df', max_count - df_count)

# %%
# vasc_images = vasc_df['image']

# vasc_indices, vasc_new_images = random_augmentation(vasc_images, 'vasc', max_count - vasc_count)

# %%
# akiec_images = akiec_df['image'] 

# akiec_indices, akiec_new_images = random_augmentation(akiec_images, 'akiec', max_count - akiec_count)

# %%
# bcc_images = bcc_df['image']

# bcc_indices, bcc_new_images = random_augmentation(bcc_images, 'bcc', max_count - bcc_count)

# %%
# bkl_images = bkl_df['image']

# bkl_indices, bkl_new_images = random_augmentation(bkl_images, 'bkl', max_count - bkl_count)

# %%
# mel_images = mel_df['image']

# mel_indices, mel_new_images = random_augmentation(mel_images, 'mel', max_count - mel_count)

# %%
# nv_images = nv_df['image']

# nv_indices, nv_new_images = random_augmentation(nv_images, 'nv', max_count - nv_count)

# %%
# new_images_df = pd.concat([df_new_images, vasc_new_images, akiec_new_images, bcc_new_images, bkl_new_images, mel_new_images, nv_new_images], axis=0).reset_index(drop=True)

# aug_df = pd.concat([df, new_images_df], axis=0).reset_index(drop=True)

# aug_df = aug_df.sample(frac=1).reset_index(drop=True)

# %%
pd.DataFrame(df['dx'].value_counts()).reset_index()
# Out:
#       dx  count
# 0     nv   6705
# 1    mel   1113
# 2    bkl   1099
# 3    bcc    514
# 4  akiec    327
# 5   vasc    142
# 6     df    115

# %%
#aug_df.shape

# %%
# for i in range(12, 18):

#     plt.subplot(1, 3, 1)

#     plt.imshow(mel_df['image'].iloc[mel_indices[i]])

#     plt.title('Original')

#     plt.axis('off')



#     plt.subplot(1, 3, 2)

#     plt.imshow(mel_new_images['image'].iloc[i])

#     plt.title('Augmented')

#     plt.axis('off')



#     plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

labelEncoder = LabelEncoder()

df['label'] = labelEncoder.fit_transform(df['dx'])

# %%
x = np.asarray(df['image'].to_list())

y = to_categorical(df['label'], num_classes=7)



x_train, x_test, y_train, y_test = train_test_split(

    x, y, test_size=0.20, random_state=42, shuffle=True, stratify=y

)

# %% [markdown]
# # **Model setup**

# %%
# !pip install -q efficientnet
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models

def create_resnet_student_model():
    image_size = 64
    num_classes = 7
    
    input_layer = layers.Input(shape=(image_size, image_size, 3))
    
    # ResNet50 branch
    resnet = ResNet50(include_top=False, weights='imagenet', input_shape=(image_size, image_size, 3))
    resnet.trainable = False  # Freeze the ResNet layers
    
    resnet_branch = resnet(input_layer)
    resnet_branch = layers.GlobalAveragePooling2D()(resnet_branch)
    
    # Final dense layers
    final_dense = layers.Dense(128, activation='relu')(resnet_branch)
    final_dense = layers.Dropout(0.5)(final_dense)
    final_output = layers.Dense(num_classes, activation='softmax', name='student_final_output')(final_dense)
    
    # Unified model
    student_model = models.Model(inputs=input_layer, outputs=final_output)
    
    return student_model

# %%
# Create the model
resnet_student_model = create_resnet_student_model()
resnet_student_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 2, 2, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ student_final_output (Dense)    │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,850,887 (90.98 MB)
#  Trainable params: 263,175 (1.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
import tensorflow as tf
from tensorflow.keras.metrics import Precision, Recall

class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred)
        self.recall.update_state(y_true, y_pred)

    def result(self):
        precision_value = self.precision.result()
        recall_value = self.recall.result()
        return 2 * (precision_value * recall_value) / (precision_value + recall_value + tf.keras.backend.epsilon())

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.optimizers import Adam

# Compile the model
resnet_student_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=[
        'accuracy',
        Precision(name='precision'),
        Recall(name='recall'),
        AUC(name='roc_auc'),
        F1Score(name='f1_score')  
    ]
)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

# Train the model
history = resnet_student_model.fit(
    x_train,  # Input data
    y_train,  # Target labels
    epochs=100,
    batch_size=32,
    validation_data=(x_test, y_test),
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1737814860.029161      79 service.cc:145] XLA service 0x7bba98001dc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1737814860.029213      79 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#  10/251 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3102 - f1_score: 0.2139 - loss: 1.8531 - precision: 0.4770 - recall: 0.1451 - roc_auc: 0.6391
# I0000 00:00:1737814865.452759      79 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.6277 - f1_score: 0.5762 - loss: 1.2779 - precision: 0.6631 - recall: 0.5142 - roc_auc: 0.8451 - val_accuracy: 0.6695 - val_f1_score: 0.6695 - val_loss: 1.1336 - val_precision: 0.6695 - val_recall: 0.6695 - val_roc_auc: 0.8919 - learning_rate: 0.0010
# Epoch 2/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6712 - f1_score: 0.6422 - loss: 1.1397 - precision: 0.6813 - recall: 0.6074 - roc_auc: 0.8789 - val_accuracy: 0.6695 - val_f1_score: 0.6695 - val_loss: 1.0833 - val_precision: 0.6695 - val_recall: 0.6695 - val_roc_auc: 0.9005 - learning_rate: 0.0010
# Epoch 3/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6692 - f1_score: 0.6429 - loss: 1.1294 - precision: 0.6837 - recall: 0.6069 - roc_auc: 0.8822 - val_accuracy: 0.6695 - val_f1_score: 0.6741 - val_loss: 1.0645 - val_precision: 0.6818 - val_recall: 0.6665 - val_roc_auc: 0.9030 - learning_rate: 0.0010
# Epoch 4/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6721 - f1_score: 0.6524 - loss: 1.0974 - precision: 0.6949 - recall: 0.6148 - roc_auc: 0.8903 - val_accuracy: 0.6695 - val_f1_score: 0.6776 - val_loss: 1.0601 - val_precision: 0.7192 - val_recall: 0.6405 - val_roc_auc: 0.9057 - learning_rate: 0.0010
# Epoch 5/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6693 - f1_score: 0.6519 - loss: 1.0773 - precision: 0.6983 - recall: 0.6113 - roc_auc: 0.8972 - val_accuracy: 0.6695 - val_f1_score: 0.6799 - val_loss: 1.0370 - val_precision: 0.7051 - val_recall: 0.6565 - val_roc_auc: 0.9089 - learning_rate: 0.0010
# Epoch 6/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6669 - f1_score: 0.6574 - loss: 1.0685 - precision: 0.7122 - recall: 0.6105 - roc_auc: 0.8994 - val_accuracy: 0.6695 - val_f1_score: 0.6707 - val_loss: 1.0773 - val_precision: 0.6718 - val_recall: 0.6695 - val_roc_auc: 0.9089 - learning_rate: 0.0010
# Epoch 7/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6636 - f1_score: 0.6498 - loss: 1.0767 - precision: 0.7118 - recall: 0.5981 - roc_auc: 0.8978 - val_accuracy: 0.6695 - val_f1_score: 0.6783 - val_loss: 1.0204 - val_precision: 0.6953 - val_recall: 0.6620 - val_roc_auc: 0.9126 - learning_rate: 0.0010
# Epoch 8/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6595 - f1_score: 0.6502 - loss: 1.0668 - precision: 0.7142 - recall: 0.5968 - roc_auc: 0.9009 - val_accuracy: 0.6695 - val_f1_score: 0.6765 - val_loss: 1.0160 - val_precision: 0.7479 - val_recall: 0.6176 - val_roc_auc: 0.9132 - learning_rate: 0.0010
# Epoch 9/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6695 - f1_score: 0.6585 - loss: 1.0439 - precision: 0.7237 - recall: 0.6041 - roc_auc: 0.9048 - val_accuracy: 0.6695 - val_f1_score: 0.6731 - val_loss: 1.0109 - val_precision: 0.7577 - val_recall: 0.6056 - val_roc_auc: 0.9146 - learning_rate: 0.0010
# Epoch 10/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6702 - f1_score: 0.6630 - loss: 1.0358 - precision: 0.7365 - recall: 0.6030 - roc_auc: 0.9067 - val_accuracy: 0.6695 - val_f1_score: 0.6803 - val_loss: 1.0081 - val_precision: 0.7053 - val_recall: 0.6570 - val_roc_auc: 0.9168 - learning_rate: 0.0010
# Epoch 11/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6650 - f1_score: 0.6573 - loss: 1.0459 - precision: 0.7321 - recall: 0.5965 - roc_auc: 0.9044 - val_accuracy: 0.6695 - val_f1_score: 0.6790 - val_loss: 0.9950 - val_precision: 0.7608 - val_recall: 0.6131 - val_roc_auc: 0.9170 - learning_rate: 0.0010
# Epoch 12/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6756 - f1_score: 0.6649 - loss: 1.0167 - precision: 0.7436 - recall: 0.6014 - roc_auc: 0.9096 - val_accuracy: 0.6695 - val_f1_score: 0.6761 - val_loss: 0.9891 - val_precision: 0.7621 - val_recall: 0.6076 - val_roc_auc: 0.9172 - learning_rate: 0.0010
# Epoch 13/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6737 - f1_score: 0.6718 - loss: 1.0153 - precision: 0.7546 - recall: 0.6054 - roc_auc: 0.9097 - val_accuracy: 0.6695 - val_f1_score: 0.6838 - val_loss: 0.9824 - val_precision: 0.7373 - val_recall: 0.6375 - val_roc_auc: 0.9181 - learning_rate: 0.0010
# Epoch 14/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6756 - f1_score: 0.6674 - loss: 1.0185 - precision: 0.7517 - recall: 0.6002 - roc_auc: 0.9095 - val_accuracy: 0.6700 - val_f1_score: 0.6827 - val_loss: 0.9850 - val_precision: 0.7639 - val_recall: 0.6171 - val_roc_auc: 0.9180 - learning_rate: 0.0010
# Epoch 15/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6772 - f1_score: 0.6767 - loss: 0.9972 - precision: 0.7599 - recall: 0.6100 - roc_auc: 0.9136 - val_accuracy: 0.6695 - val_f1_score: 0.6847 - val_loss: 0.9842 - val_precision: 0.7570 - val_recall: 0.6251 - val_roc_auc: 0.9186 - learning_rate: 0.0010
# Epoch 16/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6740 - f1_score: 0.6658 - loss: 1.0114 - precision: 0.7505 - recall: 0.5984 - roc_auc: 0.9111 - val_accuracy: 0.6695 - val_f1_score: 0.6801 - val_loss: 0.9904 - val_precision: 0.7714 - val_recall: 0.6081 - val_roc_auc: 0.9181 - learning_rate: 0.0010
# Epoch 17/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6764 - f1_score: 0.6743 - loss: 0.9971 - precision: 0.7644 - recall: 0.6034 - roc_auc: 0.9140 - val_accuracy: 0.6695 - val_f1_score: 0.6784 - val_loss: 0.9762 - val_precision: 0.7720 - val_recall: 0.6051 - val_roc_auc: 0.9196 - learning_rate: 2.0000e-04
# Epoch 18/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6680 - f1_score: 0.6752 - loss: 0.9879 - precision: 0.7725 - recall: 0.5998 - roc_auc: 0.9160 - val_accuracy: 0.6695 - val_f1_score: 0.6860 - val_loss: 0.9693 - val_precision: 0.7668 - val_recall: 0.6206 - val_roc_auc: 0.9200 - learning_rate: 2.0000e-04
# Epoch 19/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6728 - f1_score: 0.6748 - loss: 0.9873 - precision: 0.7637 - recall: 0.6045 - roc_auc: 0.9158 - val_accuracy: 0.6695 - val_f1_score: 0.6851 - val_loss: 0.9709 - val_precision: 0.7701 - val_recall: 0.6171 - val_roc_auc: 0.9202 - learning_rate: 2.0000e-04
# Epoch 20/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6759 - f1_score: 0.6809 - loss: 0.9742 - precision: 0.7777 - recall: 0.6056 - roc_auc: 0.9180 - val_accuracy: 0.6695 - val_f1_score: 0.6858 - val_loss: 0.9673 - val_precision: 0.7671 - val_recall: 0.6201 - val_roc_auc: 0.9208 - learning_rate: 2.0000e-04
# Epoch 21/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6745 - f1_score: 0.6710 - loss: 0.9813 - precision: 0.7656 - recall: 0.5975 - roc_auc: 0.9173 - val_accuracy: 0.6695 - val_f1_score: 0.6799 - val_loss: 0.9683 - val_precision: 0.7734 - val_recall: 0.6066 - val_roc_auc: 0.9210 - learning_rate: 2.0000e-04
# Epoch 22/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6708 - f1_score: 0.6787 - loss: 0.9746 - precision: 0.7728 - recall: 0.6052 - roc_auc: 0.9182 - val_accuracy: 0.6700 - val_f1_score: 0.6869 - val_loss: 0.9640 - val_precision: 0.7594 - val_recall: 0.6271 - val_roc_auc: 0.9214 - learning_rate: 2.0000e-04
# Epoch 23/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6646 - f1_score: 0.6713 - loss: 0.9924 - precision: 0.7673 - recall: 0.5966 - roc_auc: 0.9157 - val_accuracy: 0.6695 - val_f1_score: 0.6822 - val_loss: 0.9647 - val_precision: 0.7776 - val_recall: 0.6076 - val_roc_auc: 0.9213 - learning_rate: 2.0000e-04
# Epoch 24/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6729 - f1_score: 0.6740 - loss: 0.9737 - precision: 0.7705 - recall: 0.5990 - roc_auc: 0.9190 - val_accuracy: 0.6695 - val_f1_score: 0.6867 - val_loss: 0.9674 - val_precision: 0.7420 - val_recall: 0.6390 - val_roc_auc: 0.9215 - learning_rate: 2.0000e-04
# Epoch 25/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6685 - f1_score: 0.6699 - loss: 0.9859 - precision: 0.7692 - recall: 0.5933 - roc_auc: 0.9165 - val_accuracy: 0.6695 - val_f1_score: 0.6883 - val_loss: 0.9610 - val_precision: 0.7584 - val_recall: 0.6301 - val_roc_auc: 0.9216 - learning_rate: 2.0000e-04
# Epoch 26/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6769 - f1_score: 0.6839 - loss: 0.9637 - precision: 0.7826 - recall: 0.6073 - roc_auc: 0.9198 - val_accuracy: 0.6700 - val_f1_score: 0.6872 - val_loss: 0.9579 - val_precision: 0.7729 - val_recall: 0.6186 - val_roc_auc: 0.9217 - learning_rate: 2.0000e-04
# Epoch 27/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6703 - f1_score: 0.6701 - loss: 0.9845 - precision: 0.7741 - recall: 0.5908 - roc_auc: 0.9171 - val_accuracy: 0.6700 - val_f1_score: 0.6850 - val_loss: 0.9559 - val_precision: 0.7746 - val_recall: 0.6141 - val_roc_auc: 0.9223 - learning_rate: 2.0000e-04
# Epoch 28/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6664 - f1_score: 0.6659 - loss: 0.9889 - precision: 0.7797 - recall: 0.5813 - roc_auc: 0.9155 - val_accuracy: 0.6700 - val_f1_score: 0.6842 - val_loss: 0.9550 - val_precision: 0.7755 - val_recall: 0.6121 - val_roc_auc: 0.9221 - learning_rate: 2.0000e-04
# Epoch 29/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6769 - f1_score: 0.6826 - loss: 0.9666 - precision: 0.7837 - recall: 0.6046 - roc_auc: 0.9191 - val_accuracy: 0.6695 - val_f1_score: 0.6786 - val_loss: 0.9554 - val_precision: 0.7867 - val_recall: 0.5966 - val_roc_auc: 0.9223 - learning_rate: 2.0000e-04
# Epoch 30/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6723 - f1_score: 0.6791 - loss: 0.9745 - precision: 0.7856 - recall: 0.5981 - roc_auc: 0.9182 - val_accuracy: 0.6705 - val_f1_score: 0.6891 - val_loss: 0.9539 - val_precision: 0.7633 - val_recall: 0.6281 - val_roc_auc: 0.9223 - learning_rate: 2.0000e-04
# Epoch 31/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6704 - f1_score: 0.6695 - loss: 0.9814 - precision: 0.7753 - recall: 0.5892 - roc_auc: 0.9170 - val_accuracy: 0.6700 - val_f1_score: 0.6883 - val_loss: 0.9545 - val_precision: 0.7657 - val_recall: 0.6251 - val_roc_auc: 0.9225 - learning_rate: 2.0000e-04
# Epoch 32/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6728 - f1_score: 0.6699 - loss: 0.9819 - precision: 0.7825 - recall: 0.5856 - roc_auc: 0.9165 - val_accuracy: 0.6700 - val_f1_score: 0.6892 - val_loss: 0.9533 - val_precision: 0.7681 - val_recall: 0.6251 - val_roc_auc: 0.9225 - learning_rate: 2.0000e-04
# Epoch 33/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6677 - f1_score: 0.6754 - loss: 0.9688 - precision: 0.7868 - recall: 0.5917 - roc_auc: 0.9195 - val_accuracy: 0.6695 - val_f1_score: 0.6884 - val_loss: 0.9540 - val_precision: 0.7631 - val_recall: 0.6271 - val_roc_auc: 0.9228 - learning_rate: 2.0000e-04
# Epoch 34/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6749 - f1_score: 0.6723 - loss: 0.9744 - precision: 0.7824 - recall: 0.5895 - roc_auc: 0.9176 - val_accuracy: 0.6700 - val_f1_score: 0.6860 - val_loss: 0.9574 - val_precision: 0.7507 - val_recall: 0.6316 - val_roc_auc: 0.9230 - learning_rate: 2.0000e-04
# Epoch 35/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6754 - f1_score: 0.6811 - loss: 0.9666 - precision: 0.7885 - recall: 0.5995 - roc_auc: 0.9193 - val_accuracy: 0.6700 - val_f1_score: 0.6760 - val_loss: 0.9510 - val_precision: 0.7958 - val_recall: 0.5876 - val_roc_auc: 0.9230 - learning_rate: 2.0000e-04
# Epoch 36/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6741 - f1_score: 0.6804 - loss: 0.9598 - precision: 0.7905 - recall: 0.5973 - roc_auc: 0.9205 - val_accuracy: 0.6695 - val_f1_score: 0.6861 - val_loss: 0.9484 - val_precision: 0.7750 - val_recall: 0.6156 - val_roc_auc: 0.9233 - learning_rate: 2.0000e-04
# Epoch 37/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6770 - f1_score: 0.6778 - loss: 0.9644 - precision: 0.7921 - recall: 0.5923 - roc_auc: 0.9197 - val_accuracy: 0.6695 - val_f1_score: 0.6883 - val_loss: 0.9477 - val_precision: 0.7742 - val_recall: 0.6196 - val_roc_auc: 0.9234 - learning_rate: 2.0000e-04
# Epoch 38/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6723 - f1_score: 0.6701 - loss: 0.9718 - precision: 0.7824 - recall: 0.5860 - roc_auc: 0.9186 - val_accuracy: 0.6705 - val_f1_score: 0.6806 - val_loss: 0.9466 - val_precision: 0.7870 - val_recall: 0.5996 - val_roc_auc: 0.9232 - learning_rate: 2.0000e-04
# Epoch 39/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6738 - f1_score: 0.6813 - loss: 0.9609 - precision: 0.7922 - recall: 0.5978 - roc_auc: 0.9202 - val_accuracy: 0.6700 - val_f1_score: 0.6882 - val_loss: 0.9449 - val_precision: 0.7778 - val_recall: 0.6171 - val_roc_auc: 0.9235 - learning_rate: 2.0000e-04
# Epoch 40/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6802 - f1_score: 0.6832 - loss: 0.9489 - precision: 0.7936 - recall: 0.5998 - roc_auc: 0.9220 - val_accuracy: 0.6700 - val_f1_score: 0.6874 - val_loss: 0.9502 - val_precision: 0.7642 - val_recall: 0.6246 - val_roc_auc: 0.9234 - learning_rate: 2.0000e-04
# Epoch 41/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6741 - f1_score: 0.6840 - loss: 0.9517 - precision: 0.7911 - recall: 0.6025 - roc_auc: 0.9219 - val_accuracy: 0.6700 - val_f1_score: 0.6869 - val_loss: 0.9461 - val_precision: 0.7744 - val_recall: 0.6171 - val_roc_auc: 0.9235 - learning_rate: 2.0000e-04
# Epoch 42/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6751 - f1_score: 0.6764 - loss: 0.9613 - precision: 0.7854 - recall: 0.5940 - roc_auc: 0.9200 - val_accuracy: 0.6710 - val_f1_score: 0.6871 - val_loss: 0.9435 - val_precision: 0.7758 - val_recall: 0.6166 - val_roc_auc: 0.9239 - learning_rate: 2.0000e-04
# Epoch 43/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6743 - f1_score: 0.6776 - loss: 0.9649 - precision: 0.7936 - recall: 0.5913 - roc_auc: 0.9194 - val_accuracy: 0.6715 - val_f1_score: 0.6835 - val_loss: 0.9423 - val_precision: 0.7820 - val_recall: 0.6071 - val_roc_auc: 0.9239 - learning_rate: 2.0000e-04
# Epoch 44/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6745 - f1_score: 0.6782 - loss: 0.9565 - precision: 0.7914 - recall: 0.5934 - roc_auc: 0.9210 - val_accuracy: 0.6725 - val_f1_score: 0.6866 - val_loss: 0.9435 - val_precision: 0.7731 - val_recall: 0.6176 - val_roc_auc: 0.9238 - learning_rate: 2.0000e-04
# Epoch 45/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6711 - f1_score: 0.6731 - loss: 0.9729 - precision: 0.7888 - recall: 0.5870 - roc_auc: 0.9180 - val_accuracy: 0.6725 - val_f1_score: 0.6869 - val_loss: 0.9405 - val_precision: 0.7850 - val_recall: 0.6106 - val_roc_auc: 0.9243 - learning_rate: 2.0000e-04
# Epoch 46/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6714 - f1_score: 0.6727 - loss: 0.9761 - precision: 0.7887 - recall: 0.5866 - roc_auc: 0.9171 - val_accuracy: 0.6700 - val_f1_score: 0.6882 - val_loss: 0.9473 - val_precision: 0.7634 - val_recall: 0.6266 - val_roc_auc: 0.9240 - learning_rate: 2.0000e-04
# Epoch 47/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6740 - f1_score: 0.6770 - loss: 0.9542 - precision: 0.7872 - recall: 0.5941 - roc_auc: 0.9213 - val_accuracy: 0.6720 - val_f1_score: 0.6786 - val_loss: 0.9407 - val_precision: 0.7912 - val_recall: 0.5941 - val_roc_auc: 0.9244 - learning_rate: 2.0000e-04
# Epoch 48/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6846 - f1_score: 0.6875 - loss: 0.9433 - precision: 0.8026 - recall: 0.6014 - roc_auc: 0.9226 - val_accuracy: 0.6710 - val_f1_score: 0.6831 - val_loss: 0.9415 - val_precision: 0.7866 - val_recall: 0.6036 - val_roc_auc: 0.9242 - learning_rate: 2.0000e-04
# Epoch 49/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6723 - f1_score: 0.6759 - loss: 0.9506 - precision: 0.7939 - recall: 0.5885 - roc_auc: 0.9224 - val_accuracy: 0.6720 - val_f1_score: 0.6869 - val_loss: 0.9395 - val_precision: 0.7859 - val_recall: 0.6101 - val_roc_auc: 0.9244 - learning_rate: 4.0000e-05
# Epoch 50/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6862 - f1_score: 0.6929 - loss: 0.9283 - precision: 0.8077 - recall: 0.6067 - roc_auc: 0.9253 - val_accuracy: 0.6720 - val_f1_score: 0.6852 - val_loss: 0.9384 - val_precision: 0.7857 - val_recall: 0.6076 - val_roc_auc: 0.9245 - learning_rate: 4.0000e-05
# Epoch 51/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6847 - f1_score: 0.6864 - loss: 0.9326 - precision: 0.7973 - recall: 0.6026 - roc_auc: 0.9252 - val_accuracy: 0.6720 - val_f1_score: 0.6821 - val_loss: 0.9384 - val_precision: 0.7867 - val_recall: 0.6021 - val_roc_auc: 0.9246 - learning_rate: 4.0000e-05
# Epoch 52/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6724 - f1_score: 0.6718 - loss: 0.9576 - precision: 0.7989 - recall: 0.5797 - roc_auc: 0.9213 - val_accuracy: 0.6715 - val_f1_score: 0.6847 - val_loss: 0.9380 - val_precision: 0.7859 - val_recall: 0.6066 - val_roc_auc: 0.9246 - learning_rate: 4.0000e-05
# Epoch 53/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6795 - f1_score: 0.6821 - loss: 0.9443 - precision: 0.8000 - recall: 0.5946 - roc_auc: 0.9233 - val_accuracy: 0.6740 - val_f1_score: 0.6804 - val_loss: 0.9386 - val_precision: 0.7951 - val_recall: 0.5946 - val_roc_auc: 0.9246 - learning_rate: 4.0000e-05
# Epoch 54/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6751 - f1_score: 0.6756 - loss: 0.9565 - precision: 0.7989 - recall: 0.5854 - roc_auc: 0.9210 - val_accuracy: 0.6735 - val_f1_score: 0.6843 - val_loss: 0.9375 - val_precision: 0.7858 - val_recall: 0.6061 - val_roc_auc: 0.9245 - learning_rate: 4.0000e-05
# Epoch 55/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6692 - f1_score: 0.6766 - loss: 0.9543 - precision: 0.7976 - recall: 0.5875 - roc_auc: 0.9216 - val_accuracy: 0.6730 - val_f1_score: 0.6827 - val_loss: 0.9374 - val_precision: 0.7873 - val_recall: 0.6026 - val_roc_auc: 0.9245 - learning_rate: 4.0000e-05
# Epoch 56/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6831 - f1_score: 0.6788 - loss: 0.9402 - precision: 0.7953 - recall: 0.5921 - roc_auc: 0.9240 - val_accuracy: 0.6730 - val_f1_score: 0.6831 - val_loss: 0.9376 - val_precision: 0.7866 - val_recall: 0.6036 - val_roc_auc: 0.9244 - learning_rate: 4.0000e-05
# Epoch 57/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6916 - f1_score: 0.6952 - loss: 0.9219 - precision: 0.8086 - recall: 0.6098 - roc_auc: 0.9261 - val_accuracy: 0.6740 - val_f1_score: 0.6860 - val_loss: 0.9371 - val_precision: 0.7859 - val_recall: 0.6086 - val_roc_auc: 0.9245 - learning_rate: 4.0000e-05
# Epoch 58/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6708 - f1_score: 0.6740 - loss: 0.9636 - precision: 0.7895 - recall: 0.5881 - roc_auc: 0.9193 - val_accuracy: 0.6725 - val_f1_score: 0.6856 - val_loss: 0.9372 - val_precision: 0.7858 - val_recall: 0.6081 - val_roc_auc: 0.9246 - learning_rate: 4.0000e-05
# Epoch 59/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6769 - f1_score: 0.6774 - loss: 0.9493 - precision: 0.7968 - recall: 0.5892 - roc_auc: 0.9220 - val_accuracy: 0.6725 - val_f1_score: 0.6860 - val_loss: 0.9376 - val_precision: 0.7851 - val_recall: 0.6091 - val_roc_auc: 0.9247 - learning_rate: 4.0000e-05
# Epoch 60/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6786 - f1_score: 0.6835 - loss: 0.9431 - precision: 0.7954 - recall: 0.5992 - roc_auc: 0.9231 - val_accuracy: 0.6710 - val_f1_score: 0.6805 - val_loss: 0.9378 - val_precision: 0.7910 - val_recall: 0.5971 - val_roc_auc: 0.9247 - learning_rate: 4.0000e-05
# Epoch 61/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6767 - f1_score: 0.6749 - loss: 0.9452 - precision: 0.8009 - recall: 0.5832 - roc_auc: 0.9236 - val_accuracy: 0.6710 - val_f1_score: 0.6842 - val_loss: 0.9374 - val_precision: 0.7861 - val_recall: 0.6056 - val_roc_auc: 0.9247 - learning_rate: 8.0000e-06
# Epoch 62/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6754 - f1_score: 0.6848 - loss: 0.9538 - precision: 0.8025 - recall: 0.5972 - roc_auc: 0.9212 - val_accuracy: 0.6715 - val_f1_score: 0.6867 - val_loss: 0.9375 - val_precision: 0.7862 - val_recall: 0.6096 - val_roc_auc: 0.9247 - learning_rate: 8.0000e-06

# %%
import matplotlib.pyplot as plt

# Extract training history
history_dict = history.history

# Plot training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history_dict['loss'], label='Total Training Loss')
plt.plot(history_dict['val_loss'], label='Total Validation Loss', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and validation Accuracy for final output
plt.figure(figsize=(12, 6))
plt.plot(history_dict['accuracy'], label='Training Accuracy')
plt.plot(history_dict['val_accuracy'], label='Validation Accuracy', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy for Final Output')
plt.legend()
plt.grid(True)
plt.show()

# Plot Precision for final output
plt.figure(figsize=(12, 6))
plt.plot(history_dict['precision'], label='Training Precision')
plt.plot(history_dict['val_precision'], label='Validation Precision', linestyle='--')
plt.ylabel('Precision')
plt.title('Precision for Final Output')
plt.legend()
plt.grid(True)
plt.show()

# Plot Recall for final output
plt.figure(figsize=(12, 6))
plt.plot(history_dict['recall'], label='Training Recall')
plt.plot(history_dict['val_recall'], label='Validation Recall', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.title('Recall for Final Output')
plt.legend()
plt.grid(True)
plt.show()

# Plot F1-Score for final output
plt.figure(figsize=(12, 6))
plt.plot(history_dict['f1_score'], label='Training F1-Score')
plt.plot(history_dict['val_f1_score'], label='Validation F1-Score', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('F1-Score')
plt.title('F1-Score for Final Output')
plt.legend()
plt.grid(True)
plt.show()

# Plot ROC-AUC for final output
plt.figure(figsize=(12, 6))
plt.plot(history_dict['roc_auc'], label='Training ROC-AUC')
plt.plot(history_dict['val_roc_auc'], label='Validation ROC-AUC', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('ROC-AUC')
plt.title('ROC-AUC for Final Output')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Evaluate the student model
evaluation_results = resnet_student_model.evaluate(
    x_test,  # Test inputs
    y_test,  # Target labels for the final output
    verbose=1
)

# Optionally, print the results
print(f"Test Loss: {evaluation_results[0]}")
print(f"Test Accuracy: {evaluation_results[1]}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6607 - f1_score: 0.6741 - loss: 0.9656 - precision: 0.7747 - recall: 0.5966 - roc_auc: 0.9195
# Test Loss: 0.9370687007904053
# Test Accuracy: 0.6739889979362488

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Get predictions for the test dataset
predictions = resnet_student_model.predict(x_test, verbose=1)

# Use the final output predictions (only one output now)
y_pred_final = predictions  # Only one output, so we use the full predictions array
y_pred_classes = np.argmax(y_pred_final, axis=-1)  # Convert probabilities to class indices

# True labels for final output
y_true_final = np.argmax(y_test, axis=-1)  # Assuming y_test is one-hot encoded

# Generate confusion matrix
cm = confusion_matrix(y_true_final, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.arange(cm.shape[1]), 
            yticklabels=np.arange(cm.shape[0]))
plt.title('Confusion Matrix for Final Output')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step
